# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests 
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes  lab
#!pip install folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# usage: conda [-h] [-V] command ...
# conda: error: unrecognized arguments: lab
# Libraries imported.

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset   
with open('newyork_data.json') as json_data:
    ny_data = json.load(json_data)
neighborhoods_data = ny_data['features']

# %%
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
neighborhoods = pd.DataFrame(columns=column_names)

for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
#neighborhoods

# %%
neighborhoods['Borough'].unique()
# Out:
# array(['Bronx', 'Manhattan', 'Brooklyn', 'Queens', 'Staten Island'],
#       dtype=object)

# %% [markdown]
# # Bronx

# %%
bronx_data = neighborhoods[neighborhoods['Borough'] == 'Bronx'].reset_index(drop=True)
address = 'Bronx, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Bronx are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Bronx are 40.8466508, -73.8785937.

# %%
CLIENT_ID = 'LZGGP3NZK4W3Q2IRUBZPORHTGOHLIAI4VAJRGK3VMBH3NG4G' # your Foursquare ID
CLIENT_SECRET = 'MYDPVGGOVQ3JQKKX51V4UFEE1CUS452VV1EYW5OLCPVXBDJX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 100
radius = 700

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=700):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
bronx_venues = getNearbyVenues(names=bronx_data['Neighborhood'],
                                   latitudes=bronx_data['Latitude'],
                                   longitudes=bronx_data['Longitude']
                                  )
# Out:
# Wakefield
# Co-op City
# Eastchester
# Fieldston
# Riverdale
# Kingsbridge
# Woodlawn
# Norwood
# Williamsbridge
# Baychester
# Pelham Parkway
# City Island
# Bedford Park
# University Heights
# Morris Heights
# Fordham
# East Tremont
# West Farms
# High  Bridge
# Melrose
# Mott Haven
# Port Morris
# Longwood
# Hunts Point
# Morrisania
# Soundview
# Clason Point
# Throgs Neck
# Country Club
# Parkchester
# Westchester Square
# Van Nest
# Morris Park
# Belmont
# Spuyten Duyvil
# North Riverdale
# Pelham Bay
# Schuylerville
# Edgewater Park
# Castle Hill
# Olinville
# Pelham Gardens
# Concourse
# Unionport
# Edenwald
# Claremont Village
# Concourse Village
# Mount Eden
# Mount Hope
# Bronxdale
# Allerton
# Kingsbridge Heights

# %%
bronx_venues.groupby('Neighborhood').count()
# Out:
#                      Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Allerton                                36                      36     36
# Baychester                              43                      43     43
# Bedford Park                            51                      51     51
# Belmont                                 90                      90     90
# Bronxdale                               66                      66     66
# Castle Hill                             11                      11     11
# City Island                             36                      36     36
# Claremont Village                       22                      22     22
# Clason Point                            14                      14     14
# Co-op City                              37                      37     37
# Concourse                               41                      41     41
# Concourse Village                       50                      50     50
# Country Club                            26                      26     26
# East Tremont                            49                      49     49
# Eastchester                             28                      28     28
# Edenwald                                13                      13     13
# Edgewater Park                          35                      35     35
# Fieldston                                7                       7      7
# Fordham                                 76                      76     76
# High  Bridge                            24                      24     24
# Hunts Point                             17                      17     17
# Kingsbridge                             76                      76     76
# Kingsbridge Heights                     52                      52     52
# Longwood                                29                      29     29
# Melrose                                 70                      70     70
# Morris Heights                          22                      22     22
# Morris Park                             59                      59     59
# Morrisania                              25                      25     25
# Mott Haven                              31                      31     31
# Mount Eden                              47                      47     47
# Mount Hope                              57                      57     57
# North Riverdale                         40                      40     40
# Norwood                                 73                      73     73
# Olinville                               34                      34     34
# Parkchester                             71                      71     71
# Pelham Bay                              50                      50     50
# Pelham Gardens                          27                      27     27
# Pelham Parkway                          25                      25     25
# Port Morris                             28                      28     28
# Riverdale                               37                      37     37
# Schuylerville                           28                      28     28
# Soundview                               19                      19     19
# Spuyten Duyvil                          16                      16     16
# Throgs Neck                             18                      18     18
# Unionport                               42                      42     42
# University Heights                      40                      40     40
# Van Nest                                31                      31     31
# Wakefield                               19                      19     19
# West Farms                              45                      45     45
# Westchester Square                      56                      56     56
# Williamsbridge                          20                      20     20
# Woodlawn                                33                      33     33
#
#                      Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Allerton                         36               36              36
# Baychester                       43               43              43
# Bedford Park                     51               51              51
# Belmont                          90               90              90
# Bronxdale                        66               66              66
# Castle Hill                      11               11              11
# City Island                      36               36              36
# Claremont Village                22               22              22
# Clason Point                     14               14              14
# Co-op City                       37               37              37
# Concourse                        41               41              41
# Concourse Village                50               50              50
# Country Club                     26               26              26
# East Tremont                     49               49              49
# Eastchester                      28               28              28
# Edenwald                         13               13              13
# Edgewater Park                   35               35              35
# Fieldston                         7                7               7
# Fordham                          76               76              76
# High  Bridge                     24               24              24
# Hunts Point                      17               17              17
# Kingsbridge                      76               76              76
# Kingsbridge Heights              52               52              52
# Longwood                         29               29              29
# Melrose                          70               70              70
# Morris Heights                   22               22              22
# Morris Park                      59               59              59
# Morrisania                       25               25              25
# Mott Haven                       31               31              31
# Mount Eden                       47               47              47
# Mount Hope                       57               57              57
# North Riverdale                  40               40              40
# Norwood                          73               73              73
# Olinville                        34               34              34
# Parkchester                      71               71              71
# Pelham Bay                       50               50              50
# Pelham Gardens                   27               27              27
# Pelham Parkway                   25               25              25
# Port Morris                      28               28              28
# Riverdale                        37               37              37
# Schuylerville                    28               28              28
# Soundview                        19               19              19
# Spuyten Duyvil                   16               16              16
# Throgs Neck                      18               18              18
# Unionport                        42               42              42
# University Heights               40               40              40
# Van Nest                         31               31              31
# Wakefield                        19               19              19
# West Farms                       45               45              45
# Westchester Square               56               56              56
# Williamsbridge                   20               20              20
# Woodlawn                         33               33              33

# %%
bronx_onehot = pd.get_dummies(bronx_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
bronx_onehot['Neighborhood'] = bronx_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [bronx_onehot.columns[-1]] + list(bronx_onehot.columns[:-1])
bronx_onehot = bronx_onehot[fixed_columns]

# %%
bronx_grouped = bronx_onehot.groupby('Neighborhood').mean().reset_index() #frequency of venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = bronx_grouped['Neighborhood']

for ind in np.arange(bronx_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(bronx_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#            Neighborhood 1st Most Common Venue      2nd Most Common Venue  \
# 0              Allerton            Donut Shop                Bus Station
# 1            Baychester            Donut Shop           Department Store
# 2          Bedford Park         Deli / Bodega                Pizza Place
# 3               Belmont    Italian Restaurant                Pizza Place
# 4             Bronxdale           Pizza Place         Italian Restaurant
# 5           Castle Hill           Pizza Place                     Market
# 6           City Island       Harbor / Marina         Seafood Restaurant
# 7     Claremont Village           Pizza Place               Liquor Store
# 8          Clason Point                  Park                   Bus Stop
# 9            Co-op City           Bus Station        Fried Chicken Joint
# 10            Concourse   Fried Chicken Joint       Fast Food Restaurant
# 11    Concourse Village              Pharmacy              Deli / Bodega
# 12         Country Club           Pizza Place             Sandwich Place
# 13         East Tremont           Pizza Place                       Bank
# 14          Eastchester  Caribbean Restaurant       Fast Food Restaurant
# 15             Edenwald           Supermarket       Caribbean Restaurant
# 16       Edgewater Park         Deli / Bodega         Italian Restaurant
# 17            Fieldston                 Plaza    Health & Beauty Service
# 18              Fordham            Donut Shop         Spanish Restaurant
# 19         High  Bridge           Pizza Place                   Pharmacy
# 20          Hunts Point        Waste Facility              Deli / Bodega
# 21          Kingsbridge           Pizza Place         Mexican Restaurant
# 22  Kingsbridge Heights           Pizza Place                Bus Station
# 23             Longwood         Deli / Bodega              Grocery Store
# 24              Melrose           Pizza Place                   Pharmacy
# 25       Morris Heights            Food Truck                   Pharmacy
# 26          Morris Park           Pizza Place              Deli / Bodega
# 27           Morrisania            Donut Shop       Fast Food Restaurant
# 28           Mott Haven            Donut Shop                        Gym
# 29           Mount Eden              Pharmacy                 Food Truck
# 30           Mount Hope              Pharmacy                Pizza Place
# 31      North Riverdale           Pizza Place                Bus Station
# 32              Norwood           Pizza Place                       Park
# 33            Olinville  Caribbean Restaurant       Fast Food Restaurant
# 34          Parkchester           Pizza Place         Chinese Restaurant
# 35           Pelham Bay    Italian Restaurant                       Bank
# 36       Pelham Gardens           Bus Station                 Donut Shop
# 37       Pelham Parkway           Coffee Shop         Italian Restaurant
# 38          Port Morris                   Gym              Grocery Store
# 39            Riverdale                  Bank                Pizza Place
# 40        Schuylerville           Pizza Place                        Bar
# 41            Soundview    Chinese Restaurant              Deli / Bodega
# 42       Spuyten Duyvil                  Park                       Bank
# 43          Throgs Neck    Italian Restaurant                Pizza Place
# 44            Unionport           Pizza Place         Spanish Restaurant
# 45   University Heights   Fried Chicken Joint                Pizza Place
# 46             Van Nest           Pizza Place  Middle Eastern Restaurant
# 47            Wakefield         Deli / Bodega                   Pharmacy
# 48           West Farms                   Zoo              Deli / Bodega
# 49   Westchester Square        Sandwich Place       Fast Food Restaurant
# 50       Williamsbridge  Caribbean Restaurant                Pizza Place
# 51             Woodlawn         Deli / Bodega                        Pub
#
#             3rd Most Common Venue      4th Most Common Venue  \
# 0                     Pizza Place             Sandwich Place
# 1                     Supermarket                Bus Station
# 2                           Diner             Sandwich Place
# 3                          Bakery              Deli / Bodega
# 4                  Sandwich Place                       Bank
# 5                     Bus Station  Latin American Restaurant
# 6                   Grocery Store              Boat or Ferry
# 7                            Food                Bus Station
# 8                            Pool                      River
# 9            Fast Food Restaurant             Mattress Store
# 10                  Grocery Store                Pizza Place
# 11                          Diner                Supermarket
# 12                  Deli / Bodega                       Bank
# 13           Fast Food Restaurant                 Shoe Store
# 14                          Diner              Grocery Store
# 15                 Sandwich Place         Chinese Restaurant
# 16                    Pizza Place  Latin American Restaurant
# 17                    Art Gallery                      River
# 18                     Shoe Store          Mobile Phone Shop
# 19                    Supermarket  Latin American Restaurant
# 20  Paper / Office Supplies Store                 Restaurant
# 21                 Sandwich Place              Deli / Bodega
# 22                    Coffee Shop         Chinese Restaurant
# 23      Latin American Restaurant                 Donut Shop
# 24                    Supermarket              Grocery Store
# 25             Chinese Restaurant                Pizza Place
# 26                 Sandwich Place               Liquor Store
# 27                  Grocery Store                Pizza Place
# 28             Mexican Restaurant                Pizza Place
# 29                    Pizza Place              Grocery Store
# 30           Fast Food Restaurant              Grocery Store
# 31                  Deli / Bodega           Sushi Restaurant
# 32             Spanish Restaurant                   Pharmacy
# 33                    Bus Station                       Food
# 34                    Supermarket                Bus Station
# 35                         Bakery       Gym / Fitness Center
# 36                  Deli / Bodega                   Pharmacy
# 37                 Sandwich Place                       Bank
# 38                   Home Service           Storage Facility
# 39                           Park    Health & Beauty Service
# 40                       Pharmacy                      Diner
# 41           Fast Food Restaurant             Clothing Store
# 42                     Board Shop               Intersection
# 43                    Coffee Shop         Chinese Restaurant
# 44                 Cosmetics Shop  Latin American Restaurant
# 45                  Grocery Store         Chinese Restaurant
# 46                    Bus Station              Deli / Bodega
# 47                    Gas Station                 Food Truck
# 48                           Park                Bus Station
# 49                     Donut Shop                Pizza Place
# 50                       Pharmacy                 Restaurant
# 51                            Bar                Pizza Place
#
#         5th Most Common Venue
# 0                         Bar
# 1              Discount Store
# 2          Chinese Restaurant
# 3                        Café
# 4              Ice Cream Shop
# 5                        Bank
# 6      Thrift / Vintage Store
# 7                      Bakery
# 8   South American Restaurant
# 9           Accessories Store
# 10                 Donut Shop
# 11             Sandwich Place
# 12                     Bakery
# 13             Sandwich Place
# 14              Deli / Bodega
# 15                Gas Station
# 16                 Donut Shop
# 17                       Park
# 18        Fried Chicken Joint
# 19             Ice Cream Shop
# 20                  Juice Bar
# 21                        Bar
# 22                       Park
# 23       Fast Food Restaurant
# 24          Mobile Phone Shop
# 25              Historic Site
# 26                Coffee Shop
# 27                       Park
# 28                   Pharmacy
# 29       Fast Food Restaurant
# 30                 Donut Shop
# 31                       Pool
# 32              Deli / Bodega
# 33                 Donut Shop
# 34        American Restaurant
# 35                 Donut Shop
# 36                Supermarket
# 37                     Bakery
# 38  Latin American Restaurant
# 39        Japanese Restaurant
# 40             Ice Cream Shop
# 41        Fried Chicken Joint
# 42                   Pharmacy
# 43                        Pub
# 44              Deli / Bodega
# 45         Spanish Restaurant
# 46         Italian Restaurant
# 47        Fried Chicken Joint
# 48             Breakfast Spot
# 49              Metro Station
# 50                        Spa
# 51         Italian Restaurant

# %%
df_bronx= neighborhoods_venues_sorted.loc[[2, 19, 20, 34, 39, 41, 43]]

# %%
df_bronx
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 2   Bedford Park         Deli / Bodega           Pizza Place
# 19  High  Bridge           Pizza Place              Pharmacy
# 20   Hunts Point        Waste Facility         Deli / Bodega
# 34   Parkchester           Pizza Place    Chinese Restaurant
# 39     Riverdale                  Bank           Pizza Place
# 41     Soundview    Chinese Restaurant         Deli / Bodega
# 43   Throgs Neck    Italian Restaurant           Pizza Place
#
#             3rd Most Common Venue      4th Most Common Venue  \
# 2                           Diner             Sandwich Place
# 19                    Supermarket  Latin American Restaurant
# 20  Paper / Office Supplies Store                 Restaurant
# 34                    Supermarket                Bus Station
# 39                           Park    Health & Beauty Service
# 41           Fast Food Restaurant             Clothing Store
# 43                    Coffee Shop         Chinese Restaurant
#
#    5th Most Common Venue
# 2     Chinese Restaurant
# 19        Ice Cream Shop
# 20             Juice Bar
# 34   American Restaurant
# 39   Japanese Restaurant
# 41   Fried Chicken Joint
# 43                   Pub

# %%
bronx_data_new = bronx_data.loc[[12, 18, 23, 29, 4, 25, 27]]

# %%
bronx_data_new
# Out:
#    Borough  Neighborhood   Latitude  Longitude
# 12   Bronx  Bedford Park  40.870185 -73.885512
# 18   Bronx  High  Bridge  40.836623 -73.926102
# 23   Bronx   Hunts Point  40.809730 -73.883315
# 29   Bronx   Parkchester  40.837938 -73.856003
# 4    Bronx     Riverdale  40.890834 -73.912585
# 25   Bronx     Soundview  40.821012 -73.865746
# 27   Bronx   Throgs Neck  40.815109 -73.816350

# %%
# create map of Manhattan using latitude and longitude values
map_bronx = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(bronx_data['Latitude'], bronx_data['Longitude'], bronx_data_new['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bronx)  
    
map_bronx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Manhattan

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 40.7896239, -73.9598939.

# %%
CLIENT_ID = 'LZGGP3NZK4W3Q2IRUBZPORHTGOHLIAI4VAJRGK3VMBH3NG4G' # your Foursquare ID
CLIENT_SECRET = 'MYDPVGGOVQ3JQKKX51V4UFEE1CUS452VV1EYW5OLCPVXBDJX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 100
radius = 700

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %%
manhattan_venues.groupby('Neighborhood').count()
# Out:
#                      Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Battery Park City                      100                     100    100
# Carnegie Hill                          100                     100    100
# Central Harlem                          71                      71     71
# Chelsea                                100                     100    100
# Chinatown                              100                     100    100
# Civic Center                           100                     100    100
# Clinton                                100                     100    100
# East Harlem                             88                      88     88
# East Village                           100                     100    100
# Financial District                     100                     100    100
# Flatiron                               100                     100    100
# Gramercy                               100                     100    100
# Greenwich Village                      100                     100    100
# Hamilton Heights                        97                      97     97
# Hudson Yards                           100                     100    100
# Inwood                                 100                     100    100
# Lenox Hill                             100                     100    100
# Lincoln Square                         100                     100    100
# Little Italy                           100                     100    100
# Lower East Side                        100                     100    100
# Manhattan Valley                       100                     100    100
# Manhattanville                          71                      71     71
# Marble Hill                             56                      56     56
# Midtown                                100                     100    100
# Midtown South                          100                     100    100
# Morningside Heights                     71                      71     71
# Murray Hill                            100                     100    100
# Noho                                   100                     100    100
# Roosevelt Island                        35                      35     35
# Soho                                   100                     100    100
# Stuyvesant Town                         63                      63     63
# Sutton Place                           100                     100    100
# Tribeca                                100                     100    100
# Tudor City                             100                     100    100
# Turtle Bay                             100                     100    100
# Upper East Side                        100                     100    100
# Upper West Side                        100                     100    100
# Washington Heights                     100                     100    100
# West Village                           100                     100    100
# Yorkville                              100                     100    100
#
#                      Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Battery Park City               100              100             100
# Carnegie Hill                   100              100             100
# Central Harlem                   71               71              71
# Chelsea                         100              100             100
# Chinatown                       100              100             100
# Civic Center                    100              100             100
# Clinton                         100              100             100
# East Harlem                      88               88              88
# East Village                    100              100             100
# Financial District              100              100             100
# Flatiron                        100              100             100
# Gramercy                        100              100             100
# Greenwich Village               100              100             100
# Hamilton Heights                 97               97              97
# Hudson Yards                    100              100             100
# Inwood                          100              100             100
# Lenox Hill                      100              100             100
# Lincoln Square                  100              100             100
# Little Italy                    100              100             100
# Lower East Side                 100              100             100
# Manhattan Valley                100              100             100
# Manhattanville                   71               71              71
# Marble Hill                      56               56              56
# Midtown                         100              100             100
# Midtown South                   100              100             100
# Morningside Heights              71               71              71
# Murray Hill                     100              100             100
# Noho                            100              100             100
# Roosevelt Island                 35               35              35
# Soho                            100              100             100
# Stuyvesant Town                  63               63              63
# Sutton Place                    100              100             100
# Tribeca                         100              100             100
# Tudor City                      100              100             100
# Turtle Bay                      100              100             100
# Upper East Side                 100              100             100
# Upper West Side                 100              100             100
# Washington Heights              100              100             100
# West Village                    100              100             100
# Yorkville                       100              100             100

# %%
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]

# %%
manhattan_grouped = manhattan_onehot.groupby('Neighborhood').mean().reset_index() #frequency of venues

# %%
manhattan_grouped.shape
# Out:
# (40, 336)

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = manhattan_grouped['Neighborhood']

for ind in np.arange(manhattan_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(manhattan_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#            Neighborhood      1st Most Common Venue     2nd Most Common Venue  \
# 0     Battery Park City                       Park               Coffee Shop
# 1         Carnegie Hill                       Café               Coffee Shop
# 2        Central Harlem                        Bar        African Restaurant
# 3               Chelsea                Art Gallery               Coffee Shop
# 4             Chinatown         Chinese Restaurant                    Bakery
# 5          Civic Center                Coffee Shop                     Hotel
# 6               Clinton         Italian Restaurant      Gym / Fitness Center
# 7           East Harlem         Mexican Restaurant                    Bakery
# 8          East Village                Pizza Place              Cocktail Bar
# 9    Financial District                Coffee Shop               Pizza Place
# 10             Flatiron       Gym / Fitness Center               Yoga Studio
# 11             Gramercy                 Bagel Shop        Italian Restaurant
# 12    Greenwich Village         Italian Restaurant            Sandwich Place
# 13     Hamilton Heights                Coffee Shop             Deli / Bodega
# 14         Hudson Yards         Italian Restaurant                     Hotel
# 15               Inwood         Mexican Restaurant               Pizza Place
# 16           Lenox Hill           Sushi Restaurant        Italian Restaurant
# 17       Lincoln Square                      Plaza        Italian Restaurant
# 18         Little Italy   Mediterranean Restaurant               Pizza Place
# 19      Lower East Side               Cocktail Bar        Italian Restaurant
# 20     Manhattan Valley                Coffee Shop                      Park
# 21       Manhattanville                Coffee Shop        Seafood Restaurant
# 22          Marble Hill                Pizza Place            Sandwich Place
# 23              Midtown                Coffee Shop                   Theater
# 24        Midtown South          Korean Restaurant                     Hotel
# 25  Morningside Heights                       Park            Sandwich Place
# 26          Murray Hill                Coffee Shop            Sandwich Place
# 27                 Noho                Pizza Place               Coffee Shop
# 28     Roosevelt Island                       Park          Greek Restaurant
# 29                 Soho         Italian Restaurant  Mediterranean Restaurant
# 30      Stuyvesant Town                        Bar                Bagel Shop
# 31         Sutton Place                Coffee Shop                      Park
# 32              Tribeca                       Park       American Restaurant
# 33           Tudor City                Coffee Shop                      Café
# 34           Turtle Bay                       Park       American Restaurant
# 35      Upper East Side                    Exhibit        Italian Restaurant
# 36      Upper West Side                       Park        Italian Restaurant
# 37   Washington Heights  Latin American Restaurant        Mexican Restaurant
# 38         West Village         Italian Restaurant                  Wine Bar
# 39            Yorkville                Coffee Shop                       Bar
#
#               3rd Most Common Venue    4th Most Common Venue  \
# 0                             Hotel            Memorial Site
# 1                               Gym     Gym / Fitness Center
# 2   Southern / Soul Food Restaurant                Jazz Club
# 3                    Ice Cream Shop                   Bakery
# 4                      Optical Shop                      Bar
# 5                 French Restaurant                      Spa
# 6                         Wine Shop              Coffee Shop
# 7                   Thai Restaurant            Deli / Bodega
# 8                               Bar           Ice Cream Shop
# 9                     Memorial Site             Cocktail Bar
# 10               Italian Restaurant                     Café
# 11                        Wine Shop             Cocktail Bar
# 12                      Coffee Shop                     Café
# 13                              Bar       Mexican Restaurant
# 14             Gym / Fitness Center              Coffee Shop
# 15                         Wine Bar       Spanish Restaurant
# 16             Gym / Fitness Center                     Café
# 17            Performing Arts Venue        French Restaurant
# 18                           Bakery       Italian Restaurant
# 19                             Café       Chinese Restaurant
# 20               Chinese Restaurant              Pizza Place
# 21                    Deli / Bodega                     Park
# 22                       Donut Shop       Spanish Restaurant
# 23                            Hotel                    Plaza
# 24             Gym / Fitness Center      American Restaurant
# 25               Chinese Restaurant              Coffee Shop
# 26                            Hotel        Korean Restaurant
# 27               Italian Restaurant            Grocery Store
# 28                    Deli / Bodega              Pizza Place
# 29                   Sandwich Place                   Bakery
# 30                     Cocktail Bar               Playground
# 31             Gym / Fitness Center       Italian Restaurant
# 32                      Coffee Shop                    Hotel
# 33                             Park                      Bar
# 34               Seafood Restaurant       Italian Restaurant
# 35                           Bakery              Coffee Shop
# 36                     Dessert Shop              Coffee Shop
# 37                    Grocery Store                   Bakery
# 38                             Park  New American Restaurant
# 39               Italian Restaurant            Deli / Bodega
#
#        5th Most Common Venue
# 0                        Gym
# 1                     Bakery
# 2       Caribbean Restaurant
# 3                  Nightclub
# 4             Ice Cream Shop
# 5       Gym / Fitness Center
# 6                        Gym
# 7                       Café
# 8                  Juice Bar
# 9                  Juice Bar
# 10  Mediterranean Restaurant
# 11               Pizza Place
# 12                       Gym
# 13                      Café
# 14                       Gym
# 15                    Bakery
# 16               Coffee Shop
# 17                   Theater
# 18            Ice Cream Shop
# 19        Mexican Restaurant
# 20             Grocery Store
# 21        Chinese Restaurant
# 22             Deli / Bodega
# 23          Sushi Restaurant
# 24       Japanese Restaurant
# 25       American Restaurant
# 26      Gym / Fitness Center
# 27       Japanese Restaurant
# 28               Dry Cleaner
# 29               Coffee Shop
# 30             Boat or Ferry
# 31    Furniture / Home Store
# 32                       Spa
# 33                    Garden
# 34               Coffee Shop
# 35      Gym / Fitness Center
# 36       American Restaurant
# 37                      Café
# 38              Cocktail Bar
# 39                       Gym

# %%
df_manhattan = neighborhoods_venues_sorted.loc[[2, 4, 7, 12, 13, 16, 19, 20, 21, 24, 25, 26, 33, 36]]

# %%
df_manhattan
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 2        Central Harlem                   Bar    African Restaurant
# 4             Chinatown    Chinese Restaurant                Bakery
# 7           East Harlem    Mexican Restaurant                Bakery
# 12    Greenwich Village    Italian Restaurant        Sandwich Place
# 13     Hamilton Heights           Coffee Shop         Deli / Bodega
# 16           Lenox Hill      Sushi Restaurant    Italian Restaurant
# 19      Lower East Side          Cocktail Bar    Italian Restaurant
# 20     Manhattan Valley           Coffee Shop                  Park
# 21       Manhattanville           Coffee Shop    Seafood Restaurant
# 24        Midtown South     Korean Restaurant                 Hotel
# 25  Morningside Heights                  Park        Sandwich Place
# 26          Murray Hill           Coffee Shop        Sandwich Place
# 33           Tudor City           Coffee Shop                  Café
# 36      Upper West Side                  Park    Italian Restaurant
#
#               3rd Most Common Venue 4th Most Common Venue  \
# 2   Southern / Soul Food Restaurant             Jazz Club
# 4                      Optical Shop                   Bar
# 7                   Thai Restaurant         Deli / Bodega
# 12                      Coffee Shop                  Café
# 13                              Bar    Mexican Restaurant
# 16             Gym / Fitness Center                  Café
# 19                             Café    Chinese Restaurant
# 20               Chinese Restaurant           Pizza Place
# 21                    Deli / Bodega                  Park
# 24             Gym / Fitness Center   American Restaurant
# 25               Chinese Restaurant           Coffee Shop
# 26                            Hotel     Korean Restaurant
# 33                             Park                   Bar
# 36                     Dessert Shop           Coffee Shop
#
#    5th Most Common Venue
# 2   Caribbean Restaurant
# 4         Ice Cream Shop
# 7                   Café
# 12                   Gym
# 13                  Café
# 16           Coffee Shop
# 19    Mexican Restaurant
# 20         Grocery Store
# 21    Chinese Restaurant
# 24   Japanese Restaurant
# 25   American Restaurant
# 26  Gym / Fitness Center
# 33                Garden
# 36   American Restaurant

# %%
manhattan_data_new = manhattan_data.loc[[6, 1, 7, 18, 4, 10, 20, 25, 5, 33, 26, 16, 36, 12]]

# %%
manhattan_data_new
# Out:
#       Borough         Neighborhood   Latitude  Longitude
# 6   Manhattan       Central Harlem  40.815976 -73.943211
# 1   Manhattan            Chinatown  40.715618 -73.994279
# 7   Manhattan          East Harlem  40.792249 -73.944182
# 18  Manhattan    Greenwich Village  40.726933 -73.999914
# 4   Manhattan     Hamilton Heights  40.823604 -73.949688
# 10  Manhattan           Lenox Hill  40.768113 -73.958860
# 20  Manhattan      Lower East Side  40.717807 -73.980890
# 25  Manhattan     Manhattan Valley  40.797307 -73.964286
# 5   Manhattan       Manhattanville  40.816934 -73.957385
# 33  Manhattan        Midtown South  40.748510 -73.988713
# 26  Manhattan  Morningside Heights  40.808000 -73.963896
# 16  Manhattan          Murray Hill  40.748303 -73.978332
# 36  Manhattan           Tudor City  40.746917 -73.971219
# 12  Manhattan      Upper West Side  40.787658 -73.977059

# %%
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data_new['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Queens

# %%
queens_data = neighborhoods[neighborhoods['Borough'] == 'Queens'].reset_index(drop=True)
address = 'Queens, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Queens are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Queens are 40.7498243, -73.7976337.

# %%
CLIENT_ID = 'LZGGP3NZK4W3Q2IRUBZPORHTGOHLIAI4VAJRGK3VMBH3NG4G' # your Foursquare ID
CLIENT_SECRET = 'MYDPVGGOVQ3JQKKX51V4UFEE1CUS452VV1EYW5OLCPVXBDJX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 100
radius = 700

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
queens_venues = getNearbyVenues(names=queens_data['Neighborhood'],
                                   latitudes=queens_data['Latitude'],
                                   longitudes=queens_data['Longitude']
                                  )
# Out:
# Astoria
# Woodside
# Jackson Heights
# Elmhurst
# Howard Beach
# Corona
# Forest Hills
# Kew Gardens
# Richmond Hill
# Flushing
# Long Island City
# Sunnyside
# East Elmhurst
# Maspeth
# Ridgewood
# Glendale
# Rego Park
# Woodhaven
# Ozone Park
# South Ozone Park
# College Point
# Whitestone
# Bayside
# Auburndale
# Little Neck
# Douglaston
# Glen Oaks
# Bellerose
# Kew Gardens Hills
# Fresh Meadows
# Briarwood
# Jamaica Center
# Oakland Gardens
# Queens Village
# Hollis
# South Jamaica
# St. Albans
# Rochdale
# Springfield Gardens
# Cambria Heights
# Rosedale
# Far Rockaway
# Broad Channel
# Breezy Point
# Steinway
# Beechhurst
# Bay Terrace
# Edgemere
# Arverne
# Rockaway Beach
# Neponsit
# Murray Hill
# Floral Park
# Holliswood
# Jamaica Estates
# Queensboro Hill
# Hillcrest
# Ravenswood
# Lindenwood
# Laurelton
# Lefrak City
# Belle Harbor
# Rockaway Park
# Somerville
# Brookville
# Bellaire
# North Corona
# Forest Hills Gardens
# Jamaica Hills
# Utopia
# Pomonok
# Astoria Heights
# Hunters Point
# Sunnyside Gardens
# Blissville
# Roxbury
# Middle Village
# Malba
# Hammels
# Bayswater
# Queensbridge

# %%
queens_venues.groupby('Neighborhood').count()
# Out:
#                       Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Arverne                                  26                      26     26
# Astoria                                 100                     100    100
# Astoria Heights                          28                      28     28
# Auburndale                               55                      55     55
# Bay Terrace                              42                      42     42
# Bayside                                  86                      86     86
# Bayswater                                 7                       7      7
# Beechhurst                               27                      27     27
# Bellaire                                 28                      28     28
# Belle Harbor                             23                      23     23
# Bellerose                                37                      37     37
# Blissville                               26                      26     26
# Breezy Point                              6                       6      6
# Briarwood                                35                      35     35
# Broad Channel                            14                      14     14
# Brookville                               12                      12     12
# Cambria Heights                          21                      21     21
# College Point                            73                      73     73
# Corona                                   49                      49     49
# Douglaston                               46                      46     46
# East Elmhurst                            22                      22     22
# Edgemere                                 16                      16     16
# Elmhurst                                 76                      76     76
# Far Rockaway                             27                      27     27
# Floral Park                              30                      30     30
# Flushing                                100                     100    100
# Forest Hills                             54                      54     54
# Forest Hills Gardens                     78                      78     78
# Fresh Meadows                            47                      47     47
# Glen Oaks                                35                      35     35
# Glendale                                 31                      31     31
# Hammels                                  26                      26     26
# Hillcrest                                48                      48     48
# Hollis                                   21                      21     21
# Holliswood                               18                      18     18
# Howard Beach                             45                      45     45
# Hunters Point                           100                     100    100
# Jackson Heights                          96                      96     96
# Jamaica Center                           69                      69     69
# Jamaica Estates                          21                      21     21
# Jamaica Hills                            47                      47     47
# Kew Gardens                              70                      70     70
# Kew Gardens Hills                        26                      26     26
# Laurelton                                19                      19     19
# Lefrak City                              93                      93     93
# Lindenwood                               21                      21     21
# Little Neck                              53                      53     53
# Long Island City                        100                     100    100
# Malba                                    13                      13     13
# Maspeth                                  38                      38     38
# Middle Village                           35                      35     35
# Murray Hill                              63                      63     63
# Neponsit                                  4                       4      4
# North Corona                             46                      46     46
# Oakland Gardens                          46                      46     46
# Ozone Park                               44                      44     44
# Pomonok                                  13                      13     13
# Queens Village                           34                      34     34
# Queensboro Hill                          28                      28     28
# Queensbridge                             34                      34     34
# Ravenswood                               87                      87     87
# Rego Park                                76                      76     76
# Richmond Hill                            34                      34     34
# Ridgewood                                72                      72     72
# Rochdale                                 25                      25     25
# Rockaway Beach                           64                      64     64
# Rockaway Park                            37                      37     37
# Rosedale                                 19                      19     19
# Roxbury                                  14                      14     14
# Somerville                               10                      10     10
# South Jamaica                            21                      21     21
# South Ozone Park                         16                      16     16
# Springfield Gardens                      21                      21     21
# St. Albans                               26                      26     26
# Steinway                                 73                      73     73
# Sunnyside                                76                      76     76
# Sunnyside Gardens                        94                      94     94
# Utopia                                   24                      24     24
# Whitestone                                9                       9      9
# Woodhaven                                53                      53     53
# Woodside                                 68                      68     68
#
#                       Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Arverne                           26               26              26
# Astoria                          100              100             100
# Astoria Heights                   28               28              28
# Auburndale                        55               55              55
# Bay Terrace                       42               42              42
# Bayside                           86               86              86
# Bayswater                          7                7               7
# Beechhurst                        27               27              27
# Bellaire                          28               28              28
# Belle Harbor                      23               23              23
# Bellerose                         37               37              37
# Blissville                        26               26              26
# Breezy Point                       6                6               6
# Briarwood                         35               35              35
# Broad Channel                     14               14              14
# Brookville                        12               12              12
# Cambria Heights                   21               21              21
# College Point                     73               73              73
# Corona                            49               49              49
# Douglaston                        46               46              46
# East Elmhurst                     22               22              22
# Edgemere                          16               16              16
# Elmhurst                          76               76              76
# Far Rockaway                      27               27              27
# Floral Park                       30               30              30
# Flushing                         100              100             100
# Forest Hills                      54               54              54
# Forest Hills Gardens              78               78              78
# Fresh Meadows                     47               47              47
# Glen Oaks                         35               35              35
# Glendale                          31               31              31
# Hammels                           26               26              26
# Hillcrest                         48               48              48
# Hollis                            21               21              21
# Holliswood                        18               18              18
# Howard Beach                      45               45              45
# Hunters Point                    100              100             100
# Jackson Heights                   96               96              96
# Jamaica Center                    69               69              69
# Jamaica Estates                   21               21              21
# Jamaica Hills                     47               47              47
# Kew Gardens                       70               70              70
# Kew Gardens Hills                 26               26              26
# Laurelton                         19               19              19
# Lefrak City                       93               93              93
# Lindenwood                        21               21              21
# Little Neck                       53               53              53
# Long Island City                 100              100             100
# Malba                             13               13              13
# Maspeth                           38               38              38
# Middle Village                    35               35              35
# Murray Hill                       63               63              63
# Neponsit                           4                4               4
# North Corona                      46               46              46
# Oakland Gardens                   46               46              46
# Ozone Park                        44               44              44
# Pomonok                           13               13              13
# Queens Village                    34               34              34
# Queensboro Hill                   28               28              28
# Queensbridge                      34               34              34
# Ravenswood                        87               87              87
# Rego Park                         76               76              76
# Richmond Hill                     34               34              34
# Ridgewood                         72               72              72
# Rochdale                          25               25              25
# Rockaway Beach                    64               64              64
# Rockaway Park                     37               37              37
# Rosedale                          19               19              19
# Roxbury                           14               14              14
# Somerville                        10               10              10
# South Jamaica                     21               21              21
# South Ozone Park                  16               16              16
# Springfield Gardens               21               21              21
# St. Albans                        26               26              26
# Steinway                          73               73              73
# Sunnyside                         76               76              76
# Sunnyside Gardens                 94               94              94
# Utopia                            24               24              24
# Whitestone                         9                9               9
# Woodhaven                         53               53              53
# Woodside                          68               68              68

# %%
queens_onehot = pd.get_dummies(queens_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
queens_onehot['Neighborhood'] = queens_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [queens_onehot.columns[-1]] + list(queens_onehot.columns[:-1])
queens_onehot = queens_onehot[fixed_columns]

# %%
queens_grouped = queens_onehot.groupby('Neighborhood').mean().reset_index() #frequency of venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = queens_grouped['Neighborhood']

for ind in np.arange(queens_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(queens_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#             Neighborhood      1st Most Common Venue  \
# 0                Arverne                  Surf Spot
# 1                Astoria                        Bar
# 2        Astoria Heights        Rental Car Location
# 3             Auburndale          Korean Restaurant
# 4            Bay Terrace             Clothing Store
# 5                Bayside                        Bar
# 6              Bayswater                 Playground
# 7             Beechhurst       Gym / Fitness Center
# 8               Bellaire                Pizza Place
# 9           Belle Harbor                      Beach
# 10             Bellerose              Deli / Bodega
# 11            Blissville                 Donut Shop
# 12          Breezy Point        Monument / Landmark
# 13             Briarwood                Pizza Place
# 14         Broad Channel                   Dive Bar
# 15            Brookville              Deli / Bodega
# 16       Cambria Heights       Caribbean Restaurant
# 17         College Point                 Donut Shop
# 18                Corona         Mexican Restaurant
# 19            Douglaston         Chinese Restaurant
# 20         East Elmhurst                  Hotel Bar
# 21              Edgemere                Pizza Place
# 22              Elmhurst            Thai Restaurant
# 23          Far Rockaway         Chinese Restaurant
# 24           Floral Park          Indian Restaurant
# 25              Flushing            Bubble Tea Shop
# 26          Forest Hills                       Park
# 27  Forest Hills Gardens                     Bakery
# 28         Fresh Meadows         Chinese Restaurant
# 29             Glen Oaks                Bus Station
# 30              Glendale             Discount Store
# 31               Hammels                      Beach
# 32             Hillcrest          Mobile Phone Shop
# 33                Hollis       Fast Food Restaurant
# 34            Holliswood                 Donut Shop
# 35          Howard Beach         Italian Restaurant
# 36         Hunters Point                       Café
# 37       Jackson Heights  Latin American Restaurant
# 38        Jamaica Center           Department Store
# 39       Jamaica Estates       Fast Food Restaurant
# 40         Jamaica Hills           Department Store
# 41           Kew Gardens         Chinese Restaurant
# 42     Kew Gardens Hills                       Bank
# 43             Laurelton             Cosmetics Shop
# 44           Lefrak City             Clothing Store
# 45            Lindenwood                       Bank
# 46           Little Neck         Chinese Restaurant
# 47      Long Island City                      Hotel
# 48                 Malba                       Park
# 49               Maspeth                Pizza Place
# 50        Middle Village                 Playground
# 51           Murray Hill          Korean Restaurant
# 52              Neponsit                      Beach
# 53          North Corona  Latin American Restaurant
# 54       Oakland Gardens         Chinese Restaurant
# 55            Ozone Park                Pizza Place
# 56               Pomonok             Scenic Lookout
# 57        Queens Village                       Bank
# 58       Queensboro Hill         Chinese Restaurant
# 59          Queensbridge                      Hotel
# 60            Ravenswood         Mexican Restaurant
# 61             Rego Park                     Bakery
# 62         Richmond Hill          Indian Restaurant
# 63             Ridgewood                        Bar
# 64              Rochdale                   Pharmacy
# 65        Rockaway Beach                      Beach
# 66         Rockaway Park                      Beach
# 67              Rosedale                   Pharmacy
# 68               Roxbury                    Theater
# 69            Somerville            Harbor / Marina
# 70         South Jamaica                Pizza Place
# 71      South Ozone Park                       Park
# 72   Springfield Gardens                 Donut Shop
# 73            St. Albans       Caribbean Restaurant
# 74              Steinway         Italian Restaurant
# 75             Sunnyside                Pizza Place
# 76     Sunnyside Gardens                Pizza Place
# 77                Utopia              Deli / Bodega
# 78            Whitestone                 Bagel Shop
# 79             Woodhaven                Pizza Place
# 80              Woodside            Thai Restaurant
#
#          2nd Most Common Venue            3rd Most Common Venue  \
# 0                Metro Station                       Donut Shop
# 1             Greek Restaurant                      Coffee Shop
# 2                  Bus Station                      Pizza Place
# 3                  Pizza Place                   Cosmetics Shop
# 4                Women's Store                       Donut Shop
# 5                  Pizza Place                 Sushi Restaurant
# 6   Construction & Landscaping               Athletics & Sports
# 7           Chinese Restaurant                      Pizza Place
# 8            Convenience Store                    Deli / Bodega
# 9                          Pub                    Deli / Bodega
# 10           Mobile Phone Shop                      Pizza Place
# 11               Deli / Bodega                            Hotel
# 12         American Restaurant                            Trail
# 13               Deli / Bodega                Indian Restaurant
# 14              Sandwich Place               Chinese Restaurant
# 15        Fast Food Restaurant                    Grocery Store
# 16              Cosmetics Shop                     Liquor Store
# 17                 Pizza Place                    Deli / Bodega
# 18                 Supermarket                             Café
# 19               Deli / Bodega               Italian Restaurant
# 20                  Donut Shop              Rental Car Location
# 21               Metro Station                       Skate Park
# 22          Mexican Restaurant               Chinese Restaurant
# 23                 Pizza Place                             Bank
# 24              Ice Cream Shop                      Pizza Place
# 25          Chinese Restaurant                Hotpot Restaurant
# 26                      Bakery                 Asian Restaurant
# 27                Burger Joint                             Park
# 28                 Bus Station                         Pharmacy
# 29                  Bagel Shop                Indian Restaurant
# 30         Arts & Crafts Store                      Pizza Place
# 31                 Supermarket             Gym / Fitness Center
# 32                 Pizza Place                      Coffee Shop
# 33              Ice Cream Shop              Fried Chicken Joint
# 34           Convenience Store                Mobile Phone Shop
# 35                    Pharmacy                       Bagel Shop
# 36          Italian Restaurant                      Coffee Shop
# 37   South American Restaurant               Mexican Restaurant
# 38        Caribbean Restaurant                   Sandwich Place
# 39                    Pharmacy                   Cosmetics Shop
# 40                  Donut Shop                Indian Restaurant
# 41              Cosmetics Shop                              Bar
# 42                    Bus Stop                       Donut Shop
# 43                        Park             Caribbean Restaurant
# 44                      Bakery                       Shoe Store
# 45                 Pizza Place                           Bakery
# 46                 Coffee Shop               Italian Restaurant
# 47                 Coffee Shop                             Café
# 48               Deli / Bodega               Chinese Restaurant
# 49                       Diner                    Grocery Store
# 50                 Pizza Place                   Discount Store
# 51                 Supermarket                           Bakery
# 52                        Park                              Zoo
# 53               Deli / Bodega                      Pizza Place
# 54           Korean Restaurant                         Pharmacy
# 55                        Bank                         Pharmacy
# 56         Japanese Restaurant                              Bar
# 57                 Pizza Place             Caribbean Restaurant
# 58                        Bank                      Bus Station
# 59                     Brewery                       Playground
# 60                 Pizza Place                           Lounge
# 61               Grocery Store                       Bagel Shop
# 62                 Pizza Place                           Lounge
# 63                 Pizza Place                             Café
# 64                      Market  Southern / Soul Food Restaurant
# 65                         Bar                       Bagel Shop
# 66                 Pizza Place                       Donut Shop
# 67        Caribbean Restaurant               Chinese Restaurant
# 68              Baseball Field                             Pier
# 69              Ice Cream Shop                    Deli / Bodega
# 70         Fried Chicken Joint              Sporting Goods Shop
# 71               Deli / Bodega             Fast Food Restaurant
# 72          Chinese Restaurant                    Deli / Bodega
# 73            Basketball Court                         Pharmacy
# 74                        Café                 Sushi Restaurant
# 75          Italian Restaurant                    Grocery Store
# 76                         Bar                             Park
# 77                 Pizza Place                             Park
# 78          Italian Restaurant                      Fish Market
# 79               Deli / Bodega        Latin American Restaurant
# 80                         Bar                           Bakery
#
#         4th Most Common Venue      5th Most Common Venue
# 0              Sandwich Place                   Bus Stop
# 1   Middle Eastern Restaurant                     Bakery
# 2          Chinese Restaurant         Italian Restaurant
# 3                    Pharmacy              Deli / Bodega
# 4                  Shoe Store             Cosmetics Shop
# 5           Indian Restaurant        American Restaurant
# 6                        Park                Men's Store
# 7               Shopping Mall                Supermarket
# 8                Intersection       Fast Food Restaurant
# 9                         Spa                 Bagel Shop
# 10         Italian Restaurant         Chinese Restaurant
# 11                Bus Station               Skating Rink
# 12                Pizza Place                       Park
# 13                      Diner                 Donut Shop
# 14            Other Nightlife              Metro Station
# 15      Check Cashing Service               Liquor Store
# 16         Chinese Restaurant                   Pharmacy
# 17             Discount Store                        Gym
# 18                       Park                 Donut Shop
# 19                        Spa                       Bank
# 20             Clothing Store             Ice Cream Shop
# 21           Asian Restaurant         Seafood Restaurant
# 22  South American Restaurant  Latin American Restaurant
# 23        Fried Chicken Joint                Supermarket
# 24              Grocery Store                   Pharmacy
# 25          Korean Restaurant                     Bakery
# 26                        Bar                 Boxing Gym
# 27        Japanese Restaurant         Italian Restaurant
# 28                Pizza Place                       Park
# 29                   Pharmacy                  Gift Shop
# 30     Furniture / Home Store             Ice Cream Shop
# 31             Farmers Market                 Donut Shop
# 32                       Bank                Bus Station
# 33                     Bakery                     Lounge
# 34       Fast Food Restaurant               Optical Shop
# 35             Sandwich Place             Ice Cream Shop
# 36                    Brewery                 Food Truck
# 37                     Bakery        Peruvian Restaurant
# 38         Mexican Restaurant          Mobile Phone Shop
# 39        Fried Chicken Joint                       Bank
# 40        Fried Chicken Joint       Fast Food Restaurant
# 41                Pizza Place              Deli / Bodega
# 42                Pizza Place                Bus Station
# 43              Deli / Bodega              Jewelry Store
# 44             Cosmetics Shop           Department Store
# 45                       Café         Chinese Restaurant
# 46                       Bank          Mobile Phone Shop
# 47                Pizza Place         Mexican Restaurant
# 48             Scenic Lookout            Harbor / Marina
# 49                       Bank         Chinese Restaurant
# 50               Dance Studio               Skating Rink
# 51                Pizza Place                        Bar
# 52                Event Space         Falafel Restaurant
# 53       Gym / Fitness Center                 Food Truck
# 54               Liquor Store           Sushi Restaurant
# 55              Deli / Bodega                      Diner
# 56         Chinese Restaurant                 Bagel Shop
# 57         Chinese Restaurant                   Pharmacy
# 58                     Bakery                       Park
# 59             Baseball Field             Sandwich Place
# 60                 Bagel Shop         Chinese Restaurant
# 61                Pizza Place           Sushi Restaurant
# 62                       Bank  Latin American Restaurant
# 63                   Pharmacy                       Bank
# 64                   Bus Stop          Food & Drink Shop
# 65                  BBQ Joint           Arepa Restaurant
# 66              Deli / Bodega                   Pharmacy
# 67                 Donut Shop                Supermarket
# 68                      Trail             Scenic Lookout
# 69                 Taco Place             Sandwich Place
# 70              Grocery Store              Deli / Bodega
# 71                        Bar         Chinese Restaurant
# 72        Fried Chicken Joint                Bus Station
# 73               Liquor Store                       Café
# 74                     Bakery                 Donut Shop
# 75                        Bar                     Bakery
# 76              Grocery Store                Coffee Shop
# 77             Shop & Service                Supermarket
# 78                Coffee Shop                  Gastropub
# 79                   Pharmacy             Ice Cream Shop
# 80              Grocery Store                Pizza Place

# %%
df_queens = neighborhoods_venues_sorted.loc[[3,5,8,17,19,21,22,23,24,25,28,29,32,41,45,46,49,50,51,54,56,57,58,62,72,74,76,80]]

# %%
df_queens

# %%
queens_data_new = queens_data.loc[[23, 22, 65, 20, 25, 47, 3, 41, 9, 52, 29, 26, 56, 7, 58, 24, 13, 76, 51, 32, 70, 33, 55,
                                  8, 38, 44, 73, 1]]

# %%
# create map of Manhattan using latitude and longitude values
map_queens = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(queens_data['Latitude'], queens_data['Longitude'], queens_data_new['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_queens)  
    
map_queens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Brooklyn

# %%
brooklyn_data = neighborhoods[neighborhoods['Borough'] == 'Brooklyn'].reset_index(drop=True)
address = 'Brooklyn, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Brooklyn are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Brooklyn are 40.6501038, -73.9495823.

# %%
CLIENT_ID = 'LZGGP3NZK4W3Q2IRUBZPORHTGOHLIAI4VAJRGK3VMBH3NG4G' # your Foursquare ID
CLIENT_SECRET = 'MYDPVGGOVQ3JQKKX51V4UFEE1CUS452VV1EYW5OLCPVXBDJX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 100
radius = 700

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
brooklyn_venues = getNearbyVenues(names=brooklyn_data['Neighborhood'],
                                   latitudes=brooklyn_data['Latitude'],
                                   longitudes=brooklyn_data['Longitude']
                                  )
# Out:
# Bay Ridge
# Bensonhurst
# Sunset Park
# Greenpoint
# Gravesend
# Brighton Beach
# Sheepshead Bay
# Manhattan Terrace
# Flatbush
# Crown Heights
# East Flatbush
# Kensington
# Windsor Terrace
# Prospect Heights
# Brownsville
# Williamsburg
# Bushwick
# Bedford Stuyvesant
# Brooklyn Heights
# Cobble Hill
# Carroll Gardens
# Red Hook
# Gowanus
# Fort Greene
# Park Slope
# Cypress Hills
# East New York
# Starrett City
# Canarsie
# Flatlands
# Mill Island
# Manhattan Beach
# Coney Island
# Bath Beach
# Borough Park
# Dyker Heights
# Gerritsen Beach
# Marine Park
# Clinton Hill
# Sea Gate
# Downtown
# Boerum Hill
# Prospect Lefferts Gardens
# Ocean Hill
# City Line
# Bergen Beach
# Midwood
# Prospect Park South
# Georgetown
# East Williamsburg
# North Side
# South Side
# Ocean Parkway
# Fort Hamilton
# Ditmas Park
# Wingate
# Rugby
# Remsen Village
# New Lots
# Paerdegat Basin
# Mill Basin
# Fulton Ferry
# Vinegar Hill
# Weeksville
# Broadway Junction
# Dumbo
# Homecrest
# Highland Park
# Madison
# Erasmus

# %%
brooklyn_venues.groupby('Neighborhood').count()
# Out:
#                            Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# Bath Beach                                    74                      74
# Bay Ridge                                    100                     100
# Bedford Stuyvesant                            70                      70
# Bensonhurst                                   40                      40
# Bergen Beach                                   7                       7
# Boerum Hill                                  100                     100
# Borough Park                                  29                      29
# Brighton Beach                                62                      62
# Broadway Junction                             24                      24
# Brooklyn Heights                             100                     100
# Brownsville                                   45                      45
# Bushwick                                      74                      74
# Canarsie                                      16                      16
# Carroll Gardens                              100                     100
# City Line                                     55                      55
# Clinton Hill                                 100                     100
# Cobble Hill                                  100                     100
# Coney Island                                  50                      50
# Crown Heights                                 57                      57
# Cypress Hills                                 34                      34
# Ditmas Park                                   72                      72
# Downtown                                     100                     100
# Dumbo                                        100                     100
# Dyker Heights                                 31                      31
# East Flatbush                                 22                      22
# East New York                                 25                      25
# East Williamsburg                            100                     100
# Erasmus                                       33                      33
# Flatbush                                      30                      30
# Flatlands                                     31                      31
# Fort Greene                                  100                     100
# Fort Hamilton                                 54                      54
# Fulton Ferry                                  89                      89
# Georgetown                                    40                      40
# Gerritsen Beach                               32                      32
# Gowanus                                       72                      72
# Gravesend                                     51                      51
# Greenpoint                                   100                     100
# Highland Park                                 21                      21
# Homecrest                                     56                      56
# Kensington                                    57                      57
# Madison                                       31                      31
# Manhattan Beach                               26                      26
# Manhattan Terrace                             71                      71
# Marine Park                                   29                      29
# Midwood                                       34                      34
# Mill Basin                                    51                      51
# Mill Island                                    7                       7
# New Lots                                      27                      27
# North Side                                   100                     100
# Ocean Hill                                    30                      30
# Ocean Parkway                                 36                      36
# Paerdegat Basin                               12                      12
# Park Slope                                   100                     100
# Prospect Heights                             100                     100
# Prospect Lefferts Gardens                    100                     100
# Prospect Park South                          100                     100
# Red Hook                                      72                      72
# Remsen Village                                20                      20
# Rugby                                         40                      40
# Sea Gate                                       8                       8
# Sheepshead Bay                                57                      57
# South Side                                   100                     100
# Starrett City                                 19                      19
# Sunset Park                                   62                      62
# Vinegar Hill                                  36                      36
# Weeksville                                    37                      37
# Williamsburg                                  88                      88
# Windsor Terrace                               55                      55
# Wingate                                       35                      35
#
#                            Venue  Venue Latitude  Venue Longitude  \
# Neighborhood
# Bath Beach                    74              74               74
# Bay Ridge                    100             100              100
# Bedford Stuyvesant            70              70               70
# Bensonhurst                   40              40               40
# Bergen Beach                   7               7                7
# Boerum Hill                  100             100              100
# Borough Park                  29              29               29
# Brighton Beach                62              62               62
# Broadway Junction             24              24               24
# Brooklyn Heights             100             100              100
# Brownsville                   45              45               45
# Bushwick                      74              74               74
# Canarsie                      16              16               16
# Carroll Gardens              100             100              100
# City Line                     55              55               55
# Clinton Hill                 100             100              100
# Cobble Hill                  100             100              100
# Coney Island                  50              50               50
# Crown Heights                 57              57               57
# Cypress Hills                 34              34               34
# Ditmas Park                   72              72               72
# Downtown                     100             100              100
# Dumbo                        100             100              100
# Dyker Heights                 31              31               31
# East Flatbush                 22              22               22
# East New York                 25              25               25
# East Williamsburg            100             100              100
# Erasmus                       33              33               33
# Flatbush                      30              30               30
# Flatlands                     31              31               31
# Fort Greene                  100             100              100
# Fort Hamilton                 54              54               54
# Fulton Ferry                  89              89               89
# Georgetown                    40              40               40
# Gerritsen Beach               32              32               32
# Gowanus                       72              72               72
# Gravesend                     51              51               51
# Greenpoint                   100             100              100
# Highland Park                 21              21               21
# Homecrest                     56              56               56
# Kensington                    57              57               57
# Madison                       31              31               31
# Manhattan Beach               26              26               26
# Manhattan Terrace             71              71               71
# Marine Park                   29              29               29
# Midwood                       34              34               34
# Mill Basin                    51              51               51
# Mill Island                    7               7                7
# New Lots                      27              27               27
# North Side                   100             100              100
# Ocean Hill                    30              30               30
# Ocean Parkway                 36              36               36
# Paerdegat Basin               12              12               12
# Park Slope                   100             100              100
# Prospect Heights             100             100              100
# Prospect Lefferts Gardens    100             100              100
# Prospect Park South          100             100              100
# Red Hook                      72              72               72
# Remsen Village                20              20               20
# Rugby                         40              40               40
# Sea Gate                       8               8                8
# Sheepshead Bay                57              57               57
# South Side                   100             100              100
# Starrett City                 19              19               19
# Sunset Park                   62              62               62
# Vinegar Hill                  36              36               36
# Weeksville                    37              37               37
# Williamsburg                  88              88               88
# Windsor Terrace               55              55               55
# Wingate                       35              35               35
#
#                            Venue Category
# Neighborhood
# Bath Beach                             74
# Bay Ridge                             100
# Bedford Stuyvesant                     70
# Bensonhurst                            40
# Bergen Beach                            7
# Boerum Hill                           100
# Borough Park                           29
# Brighton Beach                         62
# Broadway Junction                      24
# Brooklyn Heights                      100
# Brownsville                            45
# Bushwick                               74
# Canarsie                               16
# Carroll Gardens                       100
# City Line                              55
# Clinton Hill                          100
# Cobble Hill                           100
# Coney Island                           50
# Crown Heights                          57
# Cypress Hills                          34
# Ditmas Park                            72
# Downtown                              100
# Dumbo                                 100
# Dyker Heights                          31
# East Flatbush                          22
# East New York                          25
# East Williamsburg                     100
# Erasmus                                33
# Flatbush                               30
# Flatlands                              31
# Fort Greene                           100
# Fort Hamilton                          54
# Fulton Ferry                           89
# Georgetown                             40
# Gerritsen Beach                        32
# Gowanus                                72
# Gravesend                              51
# Greenpoint                            100
# Highland Park                          21
# Homecrest                              56
# Kensington                             57
# Madison                                31
# Manhattan Beach                        26
# Manhattan Terrace                      71
# Marine Park                            29
# Midwood                                34
# Mill Basin                             51
# Mill Island                             7
# New Lots                               27
# North Side                            100
# Ocean Hill                             30
# Ocean Parkway                          36
# Paerdegat Basin                        12
# Park Slope                            100
# Prospect Heights                      100
# Prospect Lefferts Gardens             100
# Prospect Park South                   100
# Red Hook                               72
# Remsen Village                         20
# Rugby                                  40
# Sea Gate                                8
# Sheepshead Bay                         57
# South Side                            100
# Starrett City                          19
# Sunset Park                            62
# Vinegar Hill                           36
# Weeksville                             37
# Williamsburg                           88
# Windsor Terrace                        55
# Wingate                                35

# %%
brooklyn_onehot = pd.get_dummies(brooklyn_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
brooklyn_onehot['Neighborhood'] = brooklyn_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [brooklyn_onehot.columns[-1]] + list(brooklyn_onehot.columns[:-1])
brooklyn_onehot = brooklyn_onehot[fixed_columns]

# %%
brooklyn_grouped = brooklyn_onehot.groupby('Neighborhood').mean().reset_index() #frequency of venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = brooklyn_grouped['Neighborhood']

for ind in np.arange(brooklyn_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(brooklyn_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                  Neighborhood         1st Most Common Venue  \
# 0                  Bath Beach                   Pizza Place
# 1                   Bay Ridge                   Pizza Place
# 2          Bedford Stuyvesant                   Pizza Place
# 3                 Bensonhurst            Chinese Restaurant
# 4                Bergen Beach               Harbor / Marina
# 5                 Boerum Hill                           Bar
# 6                Borough Park                          Bank
# 7              Brighton Beach                         Beach
# 8           Broadway Junction     Latin American Restaurant
# 9            Brooklyn Heights                          Park
# 10                Brownsville                   Pizza Place
# 11                   Bushwick                           Bar
# 12                   Canarsie          Caribbean Restaurant
# 13            Carroll Gardens                   Coffee Shop
# 14                  City Line                   Pizza Place
# 15               Clinton Hill            Mexican Restaurant
# 16                Cobble Hill            Italian Restaurant
# 17               Coney Island  Theme Park Ride / Attraction
# 18              Crown Heights                   Pizza Place
# 19              Cypress Hills                   Pizza Place
# 20                Ditmas Park            Mexican Restaurant
# 21                   Downtown                   Coffee Shop
# 22                      Dumbo                          Park
# 23              Dyker Heights                           Bar
# 24              East Flatbush          Caribbean Restaurant
# 25              East New York            Spanish Restaurant
# 26          East Williamsburg                           Bar
# 27                    Erasmus          Caribbean Restaurant
# 28                   Flatbush          Caribbean Restaurant
# 29                  Flatlands                      Pharmacy
# 30                Fort Greene            Italian Restaurant
# 31              Fort Hamilton                   Pizza Place
# 32               Fulton Ferry                          Park
# 33                 Georgetown                          Bank
# 34            Gerritsen Beach               Harbor / Marina
# 35                    Gowanus                           Bar
# 36                  Gravesend                   Pizza Place
# 37                 Greenpoint                           Bar
# 38              Highland Park                   Pizza Place
# 39                  Homecrest                 Grocery Store
# 40                 Kensington               Thai Restaurant
# 41                    Madison                 Deli / Bodega
# 42            Manhattan Beach               Harbor / Marina
# 43          Manhattan Terrace                   Pizza Place
# 44                Marine Park                    Playground
# 45                    Midwood                   Pizza Place
# 46                 Mill Basin                   Pizza Place
# 47                Mill Island                          Pool
# 48                   New Lots          Fast Food Restaurant
# 49                 North Side                   Coffee Shop
# 50                 Ocean Hill                Discount Store
# 51              Ocean Parkway          Fast Food Restaurant
# 52            Paerdegat Basin               Harbor / Marina
# 53                 Park Slope                   Coffee Shop
# 54           Prospect Heights                           Bar
# 55  Prospect Lefferts Gardens          Caribbean Restaurant
# 56        Prospect Park South          Caribbean Restaurant
# 57                   Red Hook                 Boat or Ferry
# 58             Remsen Village          Caribbean Restaurant
# 59                      Rugby                Sandwich Place
# 60                   Sea Gate                         Beach
# 61             Sheepshead Bay            Italian Restaurant
# 62                 South Side                   Coffee Shop
# 63              Starrett City              Department Store
# 64                Sunset Park                   Pizza Place
# 65               Vinegar Hill                          Park
# 66                 Weeksville                          Park
# 67               Williamsburg                   Pizza Place
# 68            Windsor Terrace                 Deli / Bodega
# 69                    Wingate                   Pizza Place
#
#         2nd Most Common Venue 3rd Most Common Venue  \
# 0                        Bank                Bakery
# 1                         Spa    Italian Restaurant
# 2                 Coffee Shop         Deli / Bodega
# 3          Italian Restaurant            Donut Shop
# 4              Baseball Field                   Gym
# 5                 Coffee Shop   Arts & Crafts Store
# 6               Deli / Bodega           Pizza Place
# 7                  Restaurant                Bakery
# 8                       Diner        Discount Store
# 9                 Coffee Shop             Wine Shop
# 10        Fried Chicken Joint        Discount Store
# 11         Mexican Restaurant         Deli / Bodega
# 12                       Bank      Asian Restaurant
# 13                        Bar    Italian Restaurant
# 14         Chinese Restaurant         Grocery Store
# 15                Coffee Shop    Italian Restaurant
# 16                Coffee Shop          Cocktail Bar
# 17              Deli / Bodega                 Beach
# 18                       Café              Pharmacy
# 19                 Donut Shop  Fast Food Restaurant
# 20                Pizza Place  Caribbean Restaurant
# 21               Burger Joint     French Restaurant
# 22        American Restaurant        Scenic Lookout
# 23             Cosmetics Shop            Bagel Shop
# 24                Supermarket          Liquor Store
# 25        Fried Chicken Joint         Deli / Bodega
# 26                Coffee Shop                Bakery
# 27                Pizza Place                Bakery
# 28          Indian Restaurant           Pizza Place
# 29        Fried Chicken Joint  Fast Food Restaurant
# 30                Coffee Shop            Playground
# 31          Convenience Store          Cocktail Bar
# 32             Scenic Lookout   American Restaurant
# 33                   Pharmacy            Donut Shop
# 34              Deli / Bodega        Baseball Field
# 35                Pizza Place           Coffee Shop
# 36         Chinese Restaurant                Bakery
# 37               Cocktail Bar           Coffee Shop
# 38  Latin American Restaurant         Grocery Store
# 39                       Bank            Donut Shop
# 40              Grocery Store           Pizza Place
# 41           Sushi Restaurant           Pizza Place
# 42         Turkish Restaurant              Bus Stop
# 43                 Donut Shop              Pharmacy
# 44             Ice Cream Shop    Athletics & Sports
# 45              Deli / Bodega      Sushi Restaurant
# 46         Italian Restaurant    Chinese Restaurant
# 47            Harbor / Marina           Golf Course
# 48                Pizza Place        Breakfast Spot
# 49                Pizza Place              Wine Bar
# 50              Deli / Bodega            Donut Shop
# 51                Pizza Place          Liquor Store
# 52         Athletics & Sports         Moving Target
# 53                     Bakery   American Restaurant
# 54                  Wine Shop                  Café
# 55                Pizza Place                Bakery
# 56                Pizza Place         Grocery Store
# 57                       Park    Seafood Restaurant
# 58                 Donut Shop  Fast Food Restaurant
# 59       Caribbean Restaurant                  Bank
# 60                        Spa   American Restaurant
# 61         Turkish Restaurant    Seafood Restaurant
# 62                Pizza Place                   Bar
# 63                Bus Station              Bus Stop
# 64                     Bakery    Mexican Restaurant
# 65                Yoga Studio            Boxing Gym
# 66              Deli / Bodega        Discount Store
# 67                Coffee Shop                   Bar
# 68                       Park                  Café
# 69              Grocery Store            Donut Shop
#
#               4th Most Common Venue 5th Most Common Venue
# 0              Cantonese Restaurant    Chinese Restaurant
# 1                    Cosmetics Shop      Greek Restaurant
# 2                Chinese Restaurant                  Café
# 3                            Bakery            Bagel Shop
# 4                        Playground            Donut Shop
# 5                            Bakery         Grocery Store
# 6              Fast Food Restaurant                Bakery
# 7       Eastern European Restaurant    Russian Restaurant
# 8                        Donut Shop        Sandwich Place
# 9                Italian Restaurant           Pizza Place
# 10                    Metro Station                  Park
# 11                      Pizza Place                  Café
# 12                      Supermarket  Fast Food Restaurant
# 13                     Cocktail Bar           Pizza Place
# 14                      Coffee Shop            Donut Shop
# 15              Japanese Restaurant           Yoga Studio
# 16                      Pizza Place                   Bar
# 17                    Hot Dog Joint      Baseball Stadium
# 18  Southern / Soul Food Restaurant         Grocery Store
# 19              Fried Chicken Joint        Ice Cream Shop
# 20                   Clothing Store  Fast Food Restaurant
# 21                     Dance Studio                   Bar
# 22                      Coffee Shop         Boat or Ferry
# 23                      Yoga Studio                  Café
# 24                   Discount Store         Deli / Bodega
# 25                      Music Venue          Liquor Store
# 26                    Deli / Bodega                  Café
# 27                        Juice Bar    Chinese Restaurant
# 28                   Discount Store                Lounge
# 29                           Lounge  Caribbean Restaurant
# 30                      Pizza Place             Wine Shop
# 31                             Park  Gym / Fitness Center
# 32                           Bridge    Seafood Restaurant
# 33               Chinese Restaurant    Italian Restaurant
# 34                              Bar    Seafood Restaurant
# 35               Italian Restaurant             Wine Shop
# 36               Italian Restaurant         Grocery Store
# 37                      Yoga Studio           Pizza Place
# 38  Southern / Soul Food Restaurant                  Park
# 39               Chinese Restaurant              Pharmacy
# 40                      Gas Station                  Café
# 41                       Donut Shop    Chinese Restaurant
# 42                             Café          Dessert Shop
# 43                           Bakery      Sushi Restaurant
# 44                         Pharmacy         Deli / Bodega
# 45                             Bank             Gift Shop
# 46                         Pharmacy        Ice Cream Shop
# 47                        Locksmith    Seafood Restaurant
# 48              Fried Chicken Joint            Playground
# 49                              Bar           Yoga Studio
# 50                   Ice Cream Shop            Playground
# 51                           Lounge           Supermarket
# 52                    Grocery Store                  Food
# 53                     Burger Joint             Gift Shop
# 54               Mexican Restaurant          Cocktail Bar
# 55                             Café          Liquor Store
# 56                       Donut Shop     Mobile Phone Shop
# 57                        Wine Shop                   Bar
# 58                   Discount Store           Fish Market
# 59                      Pizza Place    Seafood Restaurant
# 60                      Supermarket                  Park
# 61                         Pharmacy            Restaurant
# 62                         Wine Bar           Yoga Studio
# 63                      Pizza Place                  Park
# 64                             Bank         Deli / Bodega
# 65                              Gym                  Café
# 66               Chinese Restaurant                   Gym
# 67                         Wine Bar        Breakfast Spot
# 68               Italian Restaurant                 Diner
# 69                         Pharmacy   Fried Chicken Joint

# %%
df_brooklyn = neighborhoods_venues_sorted.loc[[0,2,3,10,15,27,28,29,31,36,40,41,44,45,46,52]]

# %%
df_brooklyn

# %%
brooklyn_data_new = brooklyn_data.loc[[33, 17, 1, 14, 38, 69, 8, 29, 53, 4, 11, 68, 37, 46, 60, 59]]

# %%
# create map of Manhattan using latitude and longitude values
map_brooklyn = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(brooklyn_data['Latitude'], brooklyn_data['Longitude'], brooklyn_data_new['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_brooklyn)  
    
map_brooklyn
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Staten Island

# %%
staten_data = neighborhoods[neighborhoods['Borough'] == 'Staten Island'].reset_index(drop=True)
address = 'Staten Island, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Staten Island are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Staten Island are 40.5834557, -74.1496048.

# %%
CLIENT_ID = 'LZGGP3NZK4W3Q2IRUBZPORHTGOHLIAI4VAJRGK3VMBH3NG4G' # your Foursquare ID
CLIENT_SECRET = 'MYDPVGGOVQ3JQKKX51V4UFEE1CUS452VV1EYW5OLCPVXBDJX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 100
radius = 700

# %%
staten_venues = getNearbyVenues(names=staten_data['Neighborhood'],
                                   latitudes=staten_data['Latitude'],
                                   longitudes=staten_data['Longitude']
                                  )
# Out:
# St. George
# New Brighton
# Stapleton
# Rosebank
# West Brighton
# Grymes Hill
# Todt Hill
# South Beach
# Port Richmond
# Mariner's Harbor
# Port Ivory
# Castleton Corners
# New Springville
# Travis
# New Dorp
# Oakwood
# Great Kills
# Eltingville
# Annadale
# Woodrow
# Tottenville
# Tompkinsville
# Silver Lake
# Sunnyside
# Park Hill
# Westerleigh
# Graniteville
# Arlington
# Arrochar
# Grasmere
# Old Town
# Dongan Hills
# Midland Beach
# Grant City
# New Dorp Beach
# Bay Terrace
# Huguenot
# Pleasant Plains
# Butler Manor
# Charleston
# Rossville
# Arden Heights
# Greenridge
# Heartland Village
# Chelsea
# Bloomfield
# Bulls Head
# Richmond Town
# Shore Acres
# Clifton
# Concord
# Emerson Hill
# Randall Manor
# Howland Hook
# Elm Park
# Manor Heights
# Willowbrook
# Sandy Ground
# Egbertville
# Prince's Bay
# Lighthouse Hill
# Richmond Valley
# Fox Hills

# %%
staten_venues.groupby('Neighborhood').count()
# Out:
#                    Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Annadale                              12                      12     12
# Arden Heights                          6                       6      6
# Arlington                              9                       9      9
# Arrochar                              31                      31     31
# Bay Terrace                           12                      12     12
# Bloomfield                            10                      10     10
# Bulls Head                            48                      48     48
# Butler Manor                           4                       4      4
# Castleton Corners                     35                      35     35
# Charleston                            37                      37     37
# Chelsea                               19                      19     19
# Clifton                               17                      17     17
# Concord                               17                      17     17
# Dongan Hills                          53                      53     53
# Egbertville                            9                       9      9
# Elm Park                              36                      36     36
# Eltingville                           38                      38     38
# Emerson Hill                           5                       5      5
# Fox Hills                              9                       9      9
# Graniteville                          25                      25     25
# Grant City                            29                      29     29
# Grasmere                              19                      19     19
# Great Kills                           23                      23     23
# Greenridge                            22                      22     22
# Grymes Hill                            9                       9      9
# Heartland Village                     34                      34     34
# Howland Hook                           2                       2      2
# Huguenot                              10                      10     10
# Lighthouse Hill                        8                       8      8
# Manor Heights                         16                      16     16
# Mariner's Harbor                      11                      11     11
# Midland Beach                         12                      12     12
# New Brighton                          10                      10     10
# New Dorp                              52                      52     52
# New Dorp Beach                        27                      27     27
# New Springville                       40                      40     40
# Oakwood                                4                       4      4
# Old Town                              34                      34     34
# Park Hill                             17                      17     17
# Pleasant Plains                       19                      19     19
# Port Ivory                             1                       1      1
# Port Richmond                         16                      16     16
# Prince's Bay                          11                      11     11
# Randall Manor                         20                      20     20
# Richmond Town                         24                      24     24
# Richmond Valley                       34                      34     34
# Rosebank                              29                      29     29
# Rossville                             17                      17     17
# Sandy Ground                          10                      10     10
# Shore Acres                           27                      27     27
# Silver Lake                            8                       8      8
# South Beach                            9                       9      9
# St. George                            49                      49     49
# Stapleton                             38                      38     38
# Sunnyside                             14                      14     14
# Todt Hill                              4                       4      4
# Tompkinsville                         49                      49     49
# Tottenville                            9                       9      9
# Travis                                18                      18     18
# West Brighton                         52                      52     52
# Westerleigh                           34                      34     34
# Willowbrook                            8                       8      8
# Woodrow                               17                      17     17
#
#                    Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Annadale                       12               12              12
# Arden Heights                   6                6               6
# Arlington                       9                9               9
# Arrochar                       31               31              31
# Bay Terrace                    12               12              12
# Bloomfield                     10               10              10
# Bulls Head                     48               48              48
# Butler Manor                    4                4               4
# Castleton Corners              35               35              35
# Charleston                     37               37              37
# Chelsea                        19               19              19
# Clifton                        17               17              17
# Concord                        17               17              17
# Dongan Hills                   53               53              53
# Egbertville                     9                9               9
# Elm Park                       36               36              36
# Eltingville                    38               38              38
# Emerson Hill                    5                5               5
# Fox Hills                       9                9               9
# Graniteville                   25               25              25
# Grant City                     29               29              29
# Grasmere                       19               19              19
# Great Kills                    23               23              23
# Greenridge                     22               22              22
# Grymes Hill                     9                9               9
# Heartland Village              34               34              34
# Howland Hook                    2                2               2
# Huguenot                       10               10              10
# Lighthouse Hill                 8                8               8
# Manor Heights                  16               16              16
# Mariner's Harbor               11               11              11
# Midland Beach                  12               12              12
# New Brighton                   10               10              10
# New Dorp                       52               52              52
# New Dorp Beach                 27               27              27
# New Springville                40               40              40
# Oakwood                         4                4               4
# Old Town                       34               34              34
# Park Hill                      17               17              17
# Pleasant Plains                19               19              19
# Port Ivory                      1                1               1
# Port Richmond                  16               16              16
# Prince's Bay                   11               11              11
# Randall Manor                  20               20              20
# Richmond Town                  24               24              24
# Richmond Valley                34               34              34
# Rosebank                       29               29              29
# Rossville                      17               17              17
# Sandy Ground                   10               10              10
# Shore Acres                    27               27              27
# Silver Lake                     8                8               8
# South Beach                     9                9               9
# St. George                     49               49              49
# Stapleton                      38               38              38
# Sunnyside                      14               14              14
# Todt Hill                       4                4               4
# Tompkinsville                  49               49              49
# Tottenville                     9                9               9
# Travis                         18               18              18
# West Brighton                  52               52              52
# Westerleigh                    34               34              34
# Willowbrook                     8                8               8
# Woodrow                        17               17              17

# %%
staten_onehot = pd.get_dummies(staten_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
staten_onehot['Neighborhood'] = staten_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [staten_onehot.columns[-1]] + list(staten_onehot.columns[:-1])
staten_onehot = staten_onehot[fixed_columns]

# %%
staten_grouped = staten_onehot.groupby('Neighborhood').mean().reset_index() #frequency of venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = staten_grouped['Neighborhood']

for ind in np.arange(staten_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(staten_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#          Neighborhood     1st Most Common Venue 2nd Most Common Venue  \
# 0            Annadale               Pizza Place            Restaurant
# 1       Arden Heights               Pizza Place              Pharmacy
# 2           Arlington             Deli / Bodega         Boat or Ferry
# 3            Arrochar                  Bus Stop           Pizza Place
# 4         Bay Terrace               Supermarket            Donut Shop
# 5          Bloomfield            Baseball Field      Department Store
# 6          Bulls Head                  Bus Stop                 Diner
# 7        Butler Manor                      Pool        Baseball Field
# 8   Castleton Corners               Pizza Place                  Bank
# 9          Charleston             Big Box Store        Cosmetics Shop
# 10            Chelsea             Deli / Bodega    Spanish Restaurant
# 11            Clifton             Grocery Store         Deli / Bodega
# 12            Concord                  Bus Stop         Grocery Store
# 13       Dongan Hills        Italian Restaurant           Pizza Place
# 14        Egbertville                      Park          Home Service
# 15           Elm Park               Pizza Place         Deli / Bodega
# 16        Eltingville          Sushi Restaurant           Pizza Place
# 17       Emerson Hill                  Pharmacy                  Food
# 18          Fox Hills                  Bus Stop          Intersection
# 19       Graniteville             Grocery Store          Intersection
# 20         Grant City      Fast Food Restaurant              Bus Stop
# 21           Grasmere                Bagel Shop              Bus Stop
# 22        Great Kills        Italian Restaurant           Pizza Place
# 23         Greenridge                Food Truck            Bagel Shop
# 24        Grymes Hill       American Restaurant         Deli / Bodega
# 25  Heartland Village                  Bus Stop        Sandwich Place
# 26       Howland Hook           Harbor / Marina                Resort
# 27           Huguenot                      Bank    Italian Restaurant
# 28    Lighthouse Hill                     Trail            Bagel Shop
# 29      Manor Heights                Donut Shop         Deli / Bodega
# 30   Mariner's Harbor             Deli / Bodega    Italian Restaurant
# 31      Midland Beach            Baseball Field                 Beach
# 32       New Brighton                      Park        Discount Store
# 33           New Dorp               Pizza Place    Italian Restaurant
# 34     New Dorp Beach       American Restaurant    Italian Restaurant
# 35    New Springville      Gym / Fitness Center    Chinese Restaurant
# 36            Oakwood                       Bar        Nightlife Spot
# 37           Old Town        Italian Restaurant                  Bank
# 38          Park Hill                  Bus Stop         Grocery Store
# 39    Pleasant Plains                Donut Shop           Pizza Place
# 40         Port Ivory              Intersection           Yoga Studio
# 41      Port Richmond            Discount Store              Bus Stop
# 42       Prince's Bay               Pizza Place             Pet Store
# 43      Randall Manor                  Bus Stop                  Park
# 44      Richmond Town             Grocery Store                  Bank
# 45    Richmond Valley      Fast Food Restaurant                  Bank
# 46           Rosebank                     Beach    Italian Restaurant
# 47          Rossville               Pizza Place            Bagel Shop
# 48       Sandy Ground              Intersection                Market
# 49        Shore Acres        Italian Restaurant              Bus Stop
# 50        Silver Lake                Bagel Shop               Theater
# 51        South Beach                      Pier   American Restaurant
# 52         St. George            Clothing Store                   Bar
# 53          Stapleton   New American Restaurant        Cosmetics Shop
# 54          Sunnyside               Pizza Place            Bagel Shop
# 55          Todt Hill                  Mountain               Dog Run
# 56      Tompkinsville             Deli / Bodega              Bus Stop
# 57        Tottenville                    Bakery                  Park
# 58             Travis                     Hotel                  Park
# 59      West Brighton                  Bus Stop    Italian Restaurant
# 60        Westerleigh  Mediterranean Restaurant     Convenience Store
# 61        Willowbrook                  Bus Stop          Intersection
# 62            Woodrow             Grocery Store                 Diner
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 0                        Diner         Train Station      Sushi Restaurant
# 1                         Food          Home Service           Coffee Shop
# 2                     Bus Stop   American Restaurant           Supermarket
# 3                        Beach    Italian Restaurant         Deli / Bodega
# 4             Insurance Office                 Plaza      Sushi Restaurant
# 5            Recreation Center       Doctor's Office          Burger Joint
# 6             Sushi Restaurant         Grocery Store                  Café
# 7            Convenience Store           Yoga Studio     French Restaurant
# 8           Chinese Restaurant                 Diner        Ice Cream Shop
# 9                        Diner        Breakfast Spot          Burger Joint
# 10                        Park        Baseball Field     Martial Arts Dojo
# 11                         Bar        Cosmetics Shop           Pizza Place
# 12                 Pizza Place   Peruvian Restaurant              Pharmacy
# 13            Sushi Restaurant        Ice Cream Shop            Donut Shop
# 14              Cosmetics Shop        Clothing Store            Bagel Shop
# 15            Asian Restaurant     Mobile Phone Shop                Bakery
# 16              Ice Cream Shop    Italian Restaurant        Sandwich Place
# 17  Construction & Landscaping                Market         Grocery Store
# 18              Hardware Store        Sandwich Place    Spanish Restaurant
# 19              Cosmetics Shop           Pizza Place        Ice Cream Shop
# 20                 Pizza Place      Asian Restaurant     Convenience Store
# 21          Italian Restaurant         Deli / Bodega         Grocery Store
# 22                         Bar              Pharmacy   Japanese Restaurant
# 23        Gym / Fitness Center      Insurance Office        Discount Store
# 24                  Playground        Baseball Field    Spanish Restaurant
# 25                    Pharmacy           Coffee Shop            Donut Shop
# 26               Event Service     French Restaurant            Food Truck
# 27            Asian Restaurant                  Park        Sandwich Place
# 28                         Spa    Italian Restaurant            Art Museum
# 29                Liquor Store            Campground        Sandwich Place
# 30          Athletics & Sports           Dry Cleaner              Bus Stop
# 31                  Restaurant    Chinese Restaurant            Bagel Shop
# 32               Deli / Bodega         Garden Center            Restaurant
# 33            Sushi Restaurant         Deli / Bodega     Convenience Store
# 34                  Kids Store        Baseball Field                  Food
# 35              Sandwich Place           Coffee Shop     Mobile Phone Shop
# 36                      Lawyer                 Trail           Yoga Studio
# 37                    Bus Stop           Pizza Place              Pharmacy
# 38                       Hotel           Pizza Place                  Park
# 39              Breakfast Spot        Discount Store    Salon / Barbershop
# 40                 Event Space   Fried Chicken Joint     French Restaurant
# 41                 Pizza Place        Cosmetics Shop              Pharmacy
# 42               Tanning Salon              Pharmacy                  Bank
# 43                         Bar   Japanese Restaurant         Deli / Bodega
# 44                Liquor Store    Italian Restaurant        Ice Cream Shop
# 45         American Restaurant              Pharmacy                  Café
# 46               Grocery Store           Pizza Place        Breakfast Spot
# 47               Moving Target          Liquor Store          Climbing Gym
# 48                  Playground        Clothing Store     Fish & Chips Shop
# 49               Deli / Bodega                   Bar        Ice Cream Shop
# 50         American Restaurant          Burger Joint              Bus Stop
# 51               Deli / Bodega                  Food    Athletics & Sports
# 52          Italian Restaurant   Sporting Goods Shop    Seafood Restaurant
# 53              Discount Store        Sandwich Place    Mexican Restaurant
# 54  Construction & Landscaping         Grocery Store               Theater
# 55                       Trail                  Park           Yoga Studio
# 56          Italian Restaurant               Brewery           Pizza Place
# 57                    Bus Stop        Ice Cream Shop         Deli / Bodega
# 58          Spanish Restaurant         Deli / Bodega  Gym / Fitness Center
# 59                 Coffee Shop                  Bank            Bagel Shop
# 60        Gym / Fitness Center        Sandwich Place    Chinese Restaurant
# 61                 Pizza Place    Chinese Restaurant           Yoga Studio
# 62                  Bagel Shop                  Food    Miscellaneous Shop

# %%
df_staten = neighborhoods_venues_sorted.loc[[13,16,20,21,22,29,31,33,42,43,60,61]]

# %%
df_staten

# %%
staten_data_new = staten_data.loc[[31, 17, 33, 29, 16, 55, 32, 14, 59, 52, 25, 56]]

# %%
# create map of Manhattan using latitude and longitude values
map_staten = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(staten_data['Latitude'], staten_data['Longitude'], staten_data_new['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_staten)  
    
map_staten
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
